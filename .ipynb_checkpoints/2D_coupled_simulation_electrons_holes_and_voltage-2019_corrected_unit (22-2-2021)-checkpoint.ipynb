# %%
from fenics import *
from mshr import *
from dolfin import *
import matplotlib.pyplot as plt
import imp
import inspect

from ISHE_constants_Bi2Se3_variable import *
# imp.reload(ISHE_constants_Bi2Se3_variable)

# %%
from ISHE_constants_Bi2Se3_variable import *
print(f"{N_A_bar=}")
print(f"{n_i_bar=}")
print(f"{sigma_bar=}")
print(f"{alpha_bar=}")
print(f"{D_n_bar=}")
print(f"{D_p_bar=}")
print(f"{t_pn_bar=}")
print(f"{t_pp_bar=}")
print(f"{V_scale_factor=}")
print(f"{Vbh_l_bar=}")
print(f"{Vbh_r_bar=}")
print(f"{V_SD_bar=}")
# Out:
# N_A_bar=0.0
# n_i_bar=0.10641976547141897
# sigma_bar=0.02
# alpha_bar=0.1
# D_n_bar=8.587265625000003e-06
# D_p_bar=8.587265625000003e-06
# t_pn_bar=1.5065913370998114e+28
# t_pp_bar=1.5065913370998114e+28
# V_scale_factor=0.00033187500000000014
# Vbh_l_bar=-9.956250000000004e-05
# Vbh_r_bar=-9.956250000000004e-05
# V_SD_bar=0.0

# %%
# Read mesh from file
rectangle = Rectangle(Point(0, 0), Point(1.0, 1.0))
mesh = generate_mesh(rectangle, 500)
# mesh = UnitSquareMesh(50, 50)

# %%
# Define function space for system of concentrations
P1 = FiniteElement("P", triangle, 1)
element = MixedElement([P1, P1, P1])
V_space = FunctionSpace(mesh, element)

# %%
# Define test functions
v_1, v_2, v_3 = TestFunctions(V_space)

# %%
# Define functions for f amd g
u = Function(V_space)

# Split system functions to access components
n_bar, p_bar, V_bar = split(u)
# f, g, h = split(u)

# %%
# Define boundaries
# top     = f'near(x[1], {height})'
# bottom  = 'near(x[1], 0.0)'
right   = f'near(x[0], 1.0)'
left    = 'near(x[0], 0.0)'

# Define boundary conditions
"""
Boundary Conditions For n
"""
bc_n_left_expr = Expression("n_i_bar * exp((Eg0_e/2 - Vbh_l)/kBT_e)",
                                   n_i_bar=n_i_bar, Eg0_e=Eg0_e, Vbh_l=Vbh_l, kBT_e=kBT_e,
                                   degree=0)
bc_n_right_expr = Expression("n_i_bar * exp((Eg0_e/2 - Vbh_r)/kBT_e)", \
                                   n_i_bar=n_i_bar, Eg0_e=Eg0_e, Vbh_r=Vbh_r, kBT_e=kBT_e, \
                                   degree=0)
# bc_n_top_expr = Expression("n_i * exp((Eg0_e/2 - Vbh_l)/kBT_e)",
#                                    n_i=n_i, Eg0_e=Eg0_e, Vbh_l=Vbh_l, kBT_e=kBT_e,
#                                    degree=0)
# bc_n_bottom_expr = Expression("n_i * exp((Eg0_e/2 - Vbh_r)/kBT_e)", \
#                                    n_i=n_i, Eg0_e=Eg0_e, Vbh_r=Vbh_r, kBT_e=kBT_e, \
#                                   degree=0)
bc_n_left   = DirichletBC(V_space.sub(0), bc_n_left_expr, left)
bc_n_right  = DirichletBC(V_space.sub(0), bc_n_right_expr, right)
# bc_n_top   = DirichletBC(V_space.sub(0), bc_n_top_expr, top)
# bc_n_bottom  = DirichletBC(V_space.sub(0), bc_n_bottom_expr, bottom)

"""
Boundary Conditions For p
"""
# bc_p_left  = n_i * exp(-(Eg0_e/2 - Vbh_r) / kBT_e)
# bc_p_right = n_i * exp(-(Eg0_e/2 - Vbh_l) / kBT_e)
bc_p_left_expr = Expression("n_i_bar * exp(-(Eg0_e/2 - Vbh_l)/kBT_e)", \
                                   n_i_bar=n_i_bar, Eg0_e=Eg0_e, Vbh_l=Vbh_l, kBT_e=kBT_e, degree=0)

bc_p_right_expr = Expression("n_i_bar * exp(-(Eg0_e/2 - Vbh_r)/kBT_e)", \
                                   n_i_bar=n_i_bar, Eg0_e=Eg0_e, Vbh_r=Vbh_r, kBT_e=kBT_e, degree=0)
# bc_p_top_expr = Expression("n_i * exp(-(Eg0_e/2 - Vbh_l)/kBT_e)", \
#                                    n_i=n_i, Eg0_e=Eg0_e, Vbh_l=Vbh_l, kBT_e=kBT_e, \
#                                    degree=0)

# bc_p_bottom_expr = Expression("n_i * exp(-(Eg0_e/2 - Vbh_r)/kBT_e)", \
#                                    n_i=n_i, Eg0_e=Eg0_e, Vbh_r=Vbh_r, kBT_e=kBT_e, \
#                                    degree=0)
bc_p_left   = DirichletBC(V_space.sub(1), bc_p_left_expr, left)
bc_p_right  = DirichletBC(V_space.sub(1), bc_p_right_expr, right)
# bc_p_top   = DirichletBC(V_space.sub(1), bc_p_top_expr, top)
# bc_p_bottom  = DirichletBC(V_space.sub(1), bc_p_bottom_expr, bottom)


"""
Boundary Conditions For V
"""
# bc_V_left  = -Vbh_l + V_SD
# bc_V_right = -Vbh_r
bc_V_left_expr  = Expression("-Vbh_l_bar + V_SD_bar", Vbh_l_bar=Vbh_l_bar, V_SD_bar=V_SD_bar, degree=0)
bc_V_right_expr = Expression("-Vbh_r_bar", Vbh_r_bar=Vbh_r_bar, degree=0)
# bc_V_top_expr  = Expression("-Vbh_l + V_SD", Vbh_l=Vbh_l, V_SD=V_SD, degree=0)
# bc_V_bottom_expr = Expression("-Vbh_r", Vbh_r=Vbh_r, degree=0)


bc_V_left   = DirichletBC(V_space.sub(2), bc_V_left_expr, left)
bc_V_right  = DirichletBC(V_space.sub(2), bc_V_right_expr, right)
# bc_V_top    = DirichletBC(V_space.sub(2), bc_V_top_expr, top)
# bc_V_bottom = DirichletBC(V_space.sub(2), bc_V_bottom_expr, bottom)


# bc_f = [bc_f_top, bc_f_bottom, bc_f_right, bc_f_left]
# bc_g = [bc_g_top, bc_g_bottom, bc_g_right, bc_g_left]
# bc_array = [bc_n_left, bc_n_right, bc_n_top, bc_n_bottom, \
#             bc_p_left, bc_p_right, bc_p_top, bc_p_bottom, \
#             bc_V_left, bc_V_right, bc_V_top, bc_V_bottom]
bc_array = [bc_n_left, bc_n_right, \
            bc_p_left, bc_p_right, \
            bc_V_left, bc_V_right]

# %%
J_n_bar = n_bar * -grad(V_bar) + Constant(D_n_bar) * grad(n_bar)
J_p_bar = -(p_bar * grad(V_bar) + Constant(D_p_bar) * grad(p_bar))

# %%
x0 = 5/a

def G0_factor(mu):
    return (eps0*1e6) * epsr / ((Az * 1e-12) * (mu * 1e-4) * (N_D * 1e18)**2 * e) 

def setGeneration(P_L):
    G0 = (P_L/(hv*e))/(np.sqrt(2*np.pi)*sigma) * G0_factor(mu_n) 
    G = Expression("G0_bar * exp(-pow((x[0]-x0), 2)/(2*pow(sigma_bar,2)))" +
                   "*exp(-alpha_bar*(1-x[1]))",\
                    G0_bar=G0, x0=x0, sigma_bar=sigma_bar, alpha_bar=alpha_bar, degree=4)
    return G

# %%
alpha_bar
# Out:
# 0.1

# %%
# G = G0/Az * np.exp(-(x-x0)^2/(2*sigma^2))*exp(-alpha*(1-y))

G_bar = setGeneration(1e-9)
R_n_bar = p_bar / Constant(t_pn_bar)
R_p_bar = p_bar / Constant(t_pp_bar)

# %%
n_vec = FacetNormal(mesh)
# first line:    weak form of n part 
# second line:   weak form of p part
# third line:    weak form of V boudnary part
# fourth line:   weak form of V part
F = dot(grad(v_1), J_n_bar) * dx - v_1 * (G_bar - R_n_bar) * dx + \
    dot(grad(v_2), J_p_bar) * dx + v_2 * (G_bar - R_p_bar) * dx + \
    -v_3 * dot(grad(V_bar), n_vec) * ds + \
    dot(grad(v_3), grad(V_bar)) * dx - v_3 * (p_bar - n_bar + Constant(1.0) - Constant(N_A_bar)) * dx # V part

# %%
J = derivative(F, u)
problem = NonlinearVariationalProblem(F, u, bc_array, J )
solver  = NonlinearVariationalSolver(problem)
prm = solver.parameters

prm["nonlinear_solver"]="newton"
prm["newton_solver"]["linear_solver"] = "mumps"
prm['newton_solver']['maximum_iterations'] = 5000
prm['newton_solver']["relative_tolerance"] = 1e-2
prm["newton_solver"]["absolute_tolerance"]= 1e-2
solver.solve()
# Out:
# (1, True)

# %%
n = n_bar * N_D * 1e12 # to cm^-3 
p = p_bar * N_D * 1e12 # to cm^-3
V = V_bar * (a*1e-6)**2 * e * (N_D*1e18) / (eps0 * 1e6 * epsr)

# %%
# n_plot = plot(n_bar, title="n conc (cm^-3)", mode='color')
n_plot = plot(n, title="n conc (cm^-3)", mode='color')
plt.colorbar(n_plot)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.

# %%
# p_plot = plot(p_bar, title="p conc (cm^-3)", mode='color')
p_plot = plot(p, title="p conc (cm^-3)", mode='color')
plt.colorbar(p_plot)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.

# %%
# V_plot = plot(V_bar, title="V conc", mode='color')
V_plot = plot(V, title="V (V)", mode='color')
plt.colorbar(V_plot)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.

# %%
vtkfile_n = File("simulation/n.pvd")
vtkfile_n << project(n, V=V_space)

vtkfile_p = File("simulation/p.pvd")
vtkfile_p << project(p, V=V_space)

vtkfile_V = File("simulation/V.pvd")
vtkfile_V << project(V, V=V_space)
# Out:
# Shapes do not match: <Argument id=140403525133312> and <Product id=140405671861952>.
# ---------------------------------------------------------------------------
# UFLException                              Traceback (most recent call last)
# <ipython-input-28-592a807ed884> in <module>
#       1 vtkfile_n = File("simulation/n.pvd")
# ----> 2 vtkfile_n << project(n, V=V_space)
#       3
#       4 vtkfile_p = File("simulation/p.pvd")
#       5 vtkfile_p << project(p, V=V_space)
#
# ~/anaconda3/envs/fenics2019/lib/python3.8/site-packages/dolfin/fem/projection.py in project(v, V, bcs, mesh, function, solver_type, preconditioner_type, form_compiler_parameters)
#     127     Pv = TrialFunction(V)
#     128     a = ufl.inner(w, Pv) * dx
# --> 129     L = ufl.inner(w, v) * dx
#     130
#     131     # Assemble linear system
#
# ~/anaconda3/envs/fenics2019/lib/python3.8/site-packages/ufl/operators.py in inner(a, b)
#     167     if a.ufl_shape == () and b.ufl_shape == ():
#     168         return a * Conj(b)
# --> 169     return Inner(a, b)
#     170
#     171
#
# ~/anaconda3/envs/fenics2019/lib/python3.8/site-packages/ufl/tensoralgebra.py in __new__(cls, a, b)
#     159         ash, bsh = a.ufl_shape, b.ufl_shape
#     160         if ash != bsh:
# --> 161             error("Shapes do not match: %s and %s." % (ufl_err_str(a), ufl_err_str(b)))
#     162
#     163         # Simplification
#
# ~/anaconda3/envs/fenics2019/lib/python3.8/site-packages/ufl/log.py in error(self, *message)
#     170         "Write error message and raise an exception."
#     171         self._log.error(*message)
# --> 172         raise self._exception_type(self._format_raw(*message))
#     173
#     174     def begin(self, *message):
#
# UFLException: Shapes do not match: <Argument id=140403525133312> and <Product id=140405671861952>.

# %%
W = FunctionSpace(mesh, "P")
u_e_W = interpolate(n, W)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-2a21ad36a325> in <module>
# ----> 1 W = FunctionSpace(mesh, "P")
#       2 u_e_W = interpolate(n, W)
#
# ~/anaconda3/envs/fenics2019/lib/python3.8/site-packages/dolfin/function/functionspace.py in __init__(self, *args, **kwargs)
#      29                 pass
#      30             elif len(args) == 2:
# ---> 31                 self._init_from_ufl(*args, **kwargs)
#      32             else:
#      33                 self._init_convenience(*args, **kwargs)
#
# ~/anaconda3/envs/fenics2019/lib/python3.8/site-packages/dolfin/function/functionspace.py in _init_from_ufl(self, mesh, element, constrained_domain)
#      37         # Initialize the ufl.FunctionSpace first to check for good
#      38         # meaning
# ---> 39         ufl.FunctionSpace.__init__(self, mesh.ufl_domain(), element)
#      40
#      41         # Compile dofmap and element
#
# ~/anaconda3/envs/fenics2019/lib/python3.8/site-packages/ufl/functionspace.py in __init__(self, domain, element)
#      55                 error("Expected non-abstract domain for initalization of function space.")
#      56             else:
# ---> 57                 if element.cell() != domain_cell:
#      58                     error("Non-matching cell of finite element and domain.")
#      59
#
# AttributeError: 'str' object has no attribute 'cell'

# %%
n
# Out:
# Product(FloatValue(1000000.0), Indexed(Coefficient(FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', triangle, 1), dim=2), 3), MixedElement(FiniteElement('Lagrange', triangle, 1), FiniteElement('Lagrange', triangle, 1), FiniteElement('Lagrange', triangle, 1))), 14), MultiIndex((FixedIndex(0),))))
